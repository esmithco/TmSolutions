# %%
import pandas as pd

# %%
df_tm = pd.read_csv('Rutas_Troncales_de_TRANSMILENIO.csv')

# %%
##df_tm = pd.DataFrame(df_tm)

# %%
##df_tm.index

# %%
df_tm[0:5]
# Out:
#    objectid route_name_ruta_troncal nombre_ruta_troncal  \
# 0         1               M86-K86CV           M86-K86CV
# 1         2                     1-1                 1 U
# 2         3                     1-2                 1 P
# 3         4                     B23                 B23
# 4         5                     6-2                 6 P
#
#   servicio_unico_ruta_troncal   origen_ruta_troncal    destino_ruta_troncal  \
# 0                     M86-K86  AEROPUERTO EL DORADO  HACIENDA SANTA BARBARA
# 1                           1         UNIVERSIDADES         PORTAL ELDORADO
# 2                           1       PORTAL ELDORADO           UNIVERSIDADES
# 3                        BK23       PORTAL ELDORADO                  ALCALA
# 4                           6             PORTAL 80           UNIVERSIDADES
#
#   tipo_ruta_troncal tipo_operacion tipo_bus_ruta_troncal estado_ruta_troncal  \
# 0              DUAL       Ciclovia                  DUAL           OPERATIVA
# ...

# %%
df_tm['route_name_ruta_troncal']
# Out:
# 0      M86-K86CV
# 1            1-1
# 2            1-2
# 3            B23
# 4            6-2
#          ...
# 119          A60
# 120          F61
# 121          A61
# 122          F26
# 123          B26
# Name: route_name_ruta_troncal, Length: 124, dtype: object

# %%
df_tm[['route_name_ruta_troncal','tipo_ruta_troncal']]
# Out:
#     route_name_ruta_troncal tipo_ruta_troncal
# 0                 M86-K86CV              DUAL
# 1                       1-1           TRONCAL
# 2                       1-2           TRONCAL
# 3                       B23           TRONCAL
# 4                       6-2           TRONCAL
# ..                      ...               ...
# 119                     A60           TRONCAL
# 120                     F61           TRONCAL
# 121                     A61           TRONCAL
# 122                     F26           TRONCAL
# 123                     B26           TRONCAL
#
# [124 rows x 2 columns]

# %%
df_tm.loc[:]
# Out:
#      objectid route_name_ruta_troncal nombre_ruta_troncal  \
# 0           1               M86-K86CV           M86-K86CV
# 1           2                     1-1                 1 U
# 2           3                     1-2                 1 P
# 3           4                     B23                 B23
# 4           5                     6-2                 6 P
# ..        ...                     ...                 ...
# 119       131                     A60                 A60
# 120       132                     F61                 F61
# 121       133                     A61                 A61
# 122       134                     F26                 F26
# 123       135                     B26                 B26
#
#     servicio_unico_ruta_troncal   origen_ruta_troncal    destino_ruta_troncal  \
# 0                       M86-K86  AEROPUERTO EL DORADO  HACIENDA SANTA BARBARA
# 1                             1         UNIVERSIDADES         PORTAL ELDORADO
# ...

# %%
df_tm.loc[0:4]
# Out:
#    objectid route_name_ruta_troncal nombre_ruta_troncal  \
# 0         1               M86-K86CV           M86-K86CV
# 1         2                     1-1                 1 U
# 2         3                     1-2                 1 P
# 3         4                     B23                 B23
# 4         5                     6-2                 6 P
#
#   servicio_unico_ruta_troncal   origen_ruta_troncal    destino_ruta_troncal  \
# 0                     M86-K86  AEROPUERTO EL DORADO  HACIENDA SANTA BARBARA
# 1                           1         UNIVERSIDADES         PORTAL ELDORADO
# 2                           1       PORTAL ELDORADO           UNIVERSIDADES
# 3                        BK23       PORTAL ELDORADO                  ALCALA
# 4                           6             PORTAL 80           UNIVERSIDADES
#
#   tipo_ruta_troncal tipo_operacion tipo_bus_ruta_troncal estado_ruta_troncal  \
# 0              DUAL       Ciclovia                  DUAL           OPERATIVA
# ...

# %%
df_tm.loc[0:4,['route_name_ruta_troncal','tipo_ruta_troncal']]
# Out:
#   route_name_ruta_troncal tipo_ruta_troncal
# 0               M86-K86CV              DUAL
# 1                     1-1           TRONCAL
# 2                     1-2           TRONCAL
# 3                     B23           TRONCAL
# 4                     6-2           TRONCAL

# %%
df_tm.loc[:,['objectid']] * (-1)
# Out:
#      objectid
# 0          -1
# 1          -2
# 2          -3
# 3          -4
# 4          -5
# ..        ...
# 119      -131
# 120      -132
# 121      -133
# 122      -134
# 123      -135
#
# [124 rows x 1 columns]

# %%
df_tm.loc[:,['route_name_ruta_troncal']] == 'B23'
# Out:
#      route_name_ruta_troncal
# 0                      False
# 1                      False
# 2                      False
# 3                       True
# 4                      False
# ..                       ...
# 119                    False
# 120                    False
# 121                    False
# 122                    False
# 123                    False
#
# [124 rows x 1 columns]

# %%
df_tm.iloc[:]
# Out:
#      objectid route_name_ruta_troncal nombre_ruta_troncal  \
# 0           1               M86-K86CV           M86-K86CV
# 1           2                     1-1                 1 U
# 2           3                     1-2                 1 P
# 3           4                     B23                 B23
# 4           5                     6-2                 6 P
# ..        ...                     ...                 ...
# 119       131                     A60                 A60
# 120       132                     F61                 F61
# 121       133                     A61                 A61
# 122       134                     F26                 F26
# 123       135                     B26                 B26
#
#     servicio_unico_ruta_troncal   origen_ruta_troncal    destino_ruta_troncal  \
# 0                       M86-K86  AEROPUERTO EL DORADO  HACIENDA SANTA BARBARA
# 1                             1         UNIVERSIDADES         PORTAL ELDORADO
# ...

# %%
df_tm.iloc[:,0:3]
# Out:
#      objectid route_name_ruta_troncal nombre_ruta_troncal
# 0           1               M86-K86CV           M86-K86CV
# 1           2                     1-1                 1 U
# 2           3                     1-2                 1 P
# 3           4                     B23                 B23
# 4           5                     6-2                 6 P
# ..        ...                     ...                 ...
# 119       131                     A60                 A60
# 120       132                     F61                 F61
# 121       133                     A61                 A61
# 122       134                     F26                 F26
# 123       135                     B26                 B26
#
# [124 rows x 3 columns]

# %%
df_tm.iloc[4,2]
# Out:
# '6 P'

# %%
df_tm.iloc[:4,3:]
# Out:
#   servicio_unico_ruta_troncal   origen_ruta_troncal    destino_ruta_troncal  \
# 0                     M86-K86  AEROPUERTO EL DORADO  HACIENDA SANTA BARBARA
# 1                           1         UNIVERSIDADES         PORTAL ELDORADO
# 2                           1       PORTAL ELDORADO           UNIVERSIDADES
# 3                        BK23       PORTAL ELDORADO                  ALCALA
#
#   tipo_ruta_troncal tipo_operacion tipo_bus_ruta_troncal estado_ruta_troncal  \
# 0              DUAL       Ciclovia                  DUAL           OPERATIVA
# 1           TRONCAL         Normal          BIARTICULADO           OPERATIVA
# 2           TRONCAL         Normal          BIARTICULADO           OPERATIVA
# 3           TRONCAL         Normal          BIARTICULADO           OPERATIVA
#
#    longitud_ruta_troncal                                globalid
# 0              53.627651  {3E7EA1AA-FD8B-4358-A23A-09F753C45346}
# 1              11.819231  {E7A0492E-2EE7-437C-8115-ADB66463EEE8}
# ...

# %%
df_tm.groupby('tipo_ruta_troncal').count().head()
# Out:
#                    objectid  route_name_ruta_troncal  nombre_ruta_troncal  \
# tipo_ruta_troncal
# DUAL                     19                       19                   19
# TRONCAL                 105                      105                  105
#
#                    servicio_unico_ruta_troncal  origen_ruta_troncal  \
# tipo_ruta_troncal
# DUAL                                        19                   19
# TRONCAL                                    105                  105
#
#                    destino_ruta_troncal  tipo_operacion  \
# tipo_ruta_troncal
# DUAL                                 19              19
# TRONCAL                             105             105
#
#                    tipo_bus_ruta_troncal  estado_ruta_troncal  \
# tipo_ruta_troncal
# DUAL                                  19                   19
# TRONCAL                              105                  105
#
#                    longitud_ruta_troncal  globalid
# tipo_ruta_troncal
# ...

# %%
df_tm.groupby('tipo_ruta_troncal').min().head()
# Out:
#                    objectid route_name_ruta_troncal nombre_ruta_troncal  \
# tipo_ruta_troncal
# DUAL                      1                     C84                 C84
# TRONCAL                   2                     1-1                 1 P
#
#                   servicio_unico_ruta_troncal   origen_ruta_troncal  \
# tipo_ruta_troncal
# DUAL                                  C84-M84  AEROPUERTO EL DORADO
# TRONCAL                                     1                 AGUAS
#
#                   destino_ruta_troncal tipo_operacion tipo_bus_ruta_troncal  \
# tipo_ruta_troncal
# DUAL                   Av Suba - K114D       Ciclovia                  DUAL
# TRONCAL                          AGUAS         Normal            ARTICULADO
#
#                   estado_ruta_troncal  longitud_ruta_troncal  \
# tipo_ruta_troncal
# DUAL                        OPERATIVA               5.944270
# TRONCAL                         NUEVA               4.477823
#
# ...

# %%
df_tm.groupby('tipo_ruta_troncal').sum().head()
# Out:
#                    objectid  longitud_ruta_troncal
# tipo_ruta_troncal
# DUAL                   1194             438.502026
# TRONCAL                7430            2242.146294

# %%
df_tm.groupby('tipo_ruta_troncal').min().loc['TRONCAL'].head()
# Out:
# objectid                           2
# route_name_ruta_troncal          1-1
# nombre_ruta_troncal              1 P
# servicio_unico_ruta_troncal        1
# origen_ruta_troncal            AGUAS
# Name: TRONCAL, dtype: object

# %%
df_tm.groupby('tipo_ruta_troncal').count().reset_index()
# Out:
#   tipo_ruta_troncal  objectid  route_name_ruta_troncal  nombre_ruta_troncal  \
# 0              DUAL        19                       19                   19
# 1           TRONCAL       105                      105                  105
#
#    servicio_unico_ruta_troncal  origen_ruta_troncal  destino_ruta_troncal  \
# 0                           19                   19                    19
# 1                          105                  105                   105
#
#    tipo_operacion  tipo_bus_ruta_troncal  estado_ruta_troncal  \
# 0              19                     19                   19
# 1             105                    105                  105
#
#    longitud_ruta_troncal  globalid
# 0                     19        19
# 1                    105       105

# %%
df_tm.groupby('tipo_ruta_troncal').agg(['min','max'])
# Out:
#                   objectid      route_name_ruta_troncal             \
#                        min  max                     min        max
# tipo_ruta_troncal
# DUAL                     1  123                     C84  M86-K86CV
# TRONCAL                  2  135                     1-1        M51
#
#                   nombre_ruta_troncal            servicio_unico_ruta_troncal  \
#                                   min        max                         min
# tipo_ruta_troncal
# DUAL                              C84  M86-K86CV                     C84-M84
# TRONCAL                           1 P        M51                           1
#
#                              origen_ruta_troncal                    ...  \
#                        max                   min               max  ...
# tipo_ruta_troncal                                                   ...
# DUAL               M86-K86  AEROPUERTO EL DORADO  PUENTE DE GUADUA  ...
# ...

# %%
df_tm.groupby('tipo_ruta_troncal').agg({'origen_ruta_troncal':['min','max'], 'destino_ruta_troncal':'sum' })
# Out:
#                     origen_ruta_troncal                    \
#                                     min               max
# tipo_ruta_troncal
# DUAL               AEROPUERTO EL DORADO  PUENTE DE GUADUA
# TRONCAL                           AGUAS     UNIVERSIDADES
#
#                                                 destino_ruta_troncal
#                                                                  sum
# tipo_ruta_troncal
# DUAL               HACIENDA SANTA BARBARAPUENTE DE GUADUAHACIENDA...
# TRONCAL            PORTAL ELDORADOUNIVERSIDADESALCALAUNIVERSIDADE...

# %%
df_tm.groupby(['tipo_ruta_troncal','nombre_ruta_troncal']).count()
# Out:
#                                        objectid  route_name_ruta_troncal  \
# tipo_ruta_troncal nombre_ruta_troncal
# DUAL              C84                         1                        1
#                   C84CV                       1                        1
#                   D81                         1                        1
#                   D81-M81                     1                        1
#                   D81CV                       1                        1
# ...                                         ...                      ...
# TRONCAL           L18                         1                        1
#                   L25                         1                        1
#                   L41                         1                        1
#                   M47                         1                        1
#                   M51                         1                        1
#
# ...
